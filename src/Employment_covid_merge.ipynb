# %% [markdown]
# ### Showing trends of cases and deaths from 7th-14th of September

# %%
#Imporitng libraries
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime

# %% [markdown]
# #### Reading and preprocessing the data

# %%
#Reading the dataset
covid_data=pd.read_csv('../data/covid_large.csv')

# %%
#Converting the datatype to datetime format
covid_data['Date'] = covid_data.Date.apply(lambda d: datetime.strptime(d, '%Y-%m-%d'))

# %% [markdown]
# #### Choosing Texas state data

# %%
covid_statedata=covid_data.loc[covid_data['State'] == 'TX']

# %%
covid_statedata.dtypes
# Out:
# State                    object
# countyFIPS                int64
# County Name              object
# Date             datetime64[ns]
# Num of Cases              int64
# Num of Deaths             int64
# population                int64
# dtype: object

# %%
#Choosing one week's data from 7th-14th September
start_date=datetime(2020,9,6)
end_date=datetime(2020,9,15)
mask = (covid_statedata['Date'] > start_date) & (covid_statedata['Date'] <= end_date)

# %%
#Applying mask to the dataset 
covid = covid_statedata.loc[mask]

# %%
#Final dataset with Texas state data
covid
# Out:
#        State  countyFIPS            County Name       Date  Num of Cases  \
# 608845    TX           0  statewide unallocated 2020-09-07             0
# 608846    TX           0  statewide unallocated 2020-09-08             0
# 608847    TX           0  statewide unallocated 2020-09-09             0
# 608848    TX           0  statewide unallocated 2020-09-10             0
# 608849    TX           0  statewide unallocated 2020-09-11             0
# ...      ...         ...                    ...        ...           ...
# 669046    TX       48507          zavala county 2020-09-10           274
# 669047    TX       48507          zavala county 2020-09-11           275
# 669048    TX       48507          zavala county 2020-09-12           282
# 669049    TX       48507          zavala county 2020-09-13           282
# 669050    TX       48507          zavala county 2020-09-14           282
#
#         Num of Deaths  population
# 608845              3           0
# 608846              3           0
# 608847              3           0
# 608848              3           0
# 608849              3           0
# ...               ...         ...
# 669046             13       11840
# 669047             14       11840
# 669048             14       11840
# 669049             14       11840
# 669050             14       11840
#
# [2040 rows x 7 columns]

# %%
#Setting date as the index
covid=covid.set_index('Date')

# %%
#Grouping by date and adding all the county numbers in TX state on the same date for both cases and deaths
covid_test=covid.groupby('Date')['Num of Deaths'].sum()
covid_test1=covid.groupby('Date')['Num of Cases'].sum()

# %%
covid_test
# Out:
# Date
# 2020-09-07    13485
# 2020-09-08    13546
# 2020-09-09    13686
# 2020-09-10    13847
# 2020-09-11    13991
# 2020-09-12    14138
# 2020-09-13    14185
# 2020-09-14    14206
# Name: Num of Deaths, dtype: int64

# %% [markdown]
# #### Deaths trend for the week

# %%
ax=covid_test.plot(title='Deaths due to Covid19 in the past week',figsize=(10,5), grid=True,legend=True)
ax.set_ylabel("Deaths")
# Out:
# Text(0, 0.5, 'Deaths')

# %% [markdown]
# #### The deaths in Texas state due to Covid19 are steadily increasing in the past week from 7th-13th, than they are a bit stable from 13th to 14th.

# %% [markdown]
# #### Cases trend for the week

# %%
ax=covid_test1.plot(title='Number of Covid19 Cases in the past week',figsize=(10,5), grid=True,legend=True)
ax.set_ylabel("COVID cases")
# Out:
# Text(0, 0.5, 'COVID cases')

# %% [markdown]
# #### The cases in Texas week are steadily increasing in the past week.

# %% [markdown]
# ### Merging employee enrichment dataset with super covid dataset

# %%
#Importing libraries
import pandas as pd

# %% [markdown]
# #### Reading the data and preprocessing it

# %%
#Loading the enrichment employee dataset
emp_data=pd.read_excel('../data/employment.xlsx')

# %%
emp_data.head()
# Out:
#   Area\nCode  St  Cnty  Own  NAICS  Year  Qtr Area Type St Name        Area  \
# 0      US000  US   0.0    0     10  2020    1    Nation     NaN  U.S. TOTAL
# 1      US000  US   0.0    1     10  2020    1    Nation     NaN  U.S. TOTAL
# 2      US000  US   0.0    2     10  2020    1    Nation     NaN  U.S. TOTAL
# 3      US000  US   0.0    3     10  2020    1    Nation     NaN  U.S. TOTAL
# 4      US000  US   0.0    5     10  2020    1    Nation     NaN  U.S. TOTAL
#
#    ...                  Industry Status Code Establishment Count  \
# 0  ...  10 Total, all industries         NaN            10447240
# 1  ...  10 Total, all industries         NaN               61014
# 2  ...  10 Total, all industries         NaN               69931
# 3  ...  10 Total, all industries         NaN              171065
# 4  ...  10 Total, all industries         NaN            10145230
#
#    January Employment  February Employment  March Employment  \
# 0           147279523            147858938         147088945
# 1             2838417              2839463           2857289
# 2             4631048              4704637           4710894
# 3            14520838             14657450          14681375
# 4           125289220            125657388         124839387
#
#    Total Quarterly Wages  Average Weekly Wage  \
# 0          2341897353925                 1222
# 1            56666068074                 1532
# 2            74670024998                 1227
# 3           195835097606                 1030
# 4          2014726163247                 1237
#
#    Employment Location Quotient Relative to U.S.  \
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
#    Total Wage Location Quotient Relative to U.S.
# 0                                            1.0
# 1                                            1.0
# 2                                            1.0
# 3                                            1.0
# 4                                            1.0
#
# [5 rows x 21 columns]

# %%
#Converting all the Area names to lower case for consistency
emp_data['Area'] = emp_data['Area'].apply(lambda cn: cn.lower().strip())

# %%
#Selecting only rows which are of Area type 'County'
emp_data=emp_data.loc[emp_data['Area Type']=='County']

# %%
#Preprocessing the column to match countyFIPS in covid dataset(4 digit area codes are there as 5 digit with a leading zero so removing them)
emp_data['Area\nCode']=emp_data['Area\nCode'].apply(lambda x : x[1:] if x.startswith("0") else x)

# %%
emp_data.head(20)
# Out:
#    Area\nCode  St  Cnty  Own  NAICS  Year  Qtr Area Type  St Name  \
# 35       1001  01   1.0    0     10  2020    1    County  Alabama
# 36       1001  01   1.0    1     10  2020    1    County  Alabama
# 37       1001  01   1.0    2     10  2020    1    County  Alabama
# 38       1001  01   1.0    3     10  2020    1    County  Alabama
# 39       1001  01   1.0    5     10  2020    1    County  Alabama
# 40       1001  01   1.0    5    101  2020    1    County  Alabama
# 41       1001  01   1.0    5   1011  2020    1    County  Alabama
# 42       1001  01   1.0    5   1012  2020    1    County  Alabama
# 43       1001  01   1.0    5   1013  2020    1    County  Alabama
# 44       1001  01   1.0    5    102  2020    1    County  Alabama
# 45       1001  01   1.0    5   1021  2020    1    County  Alabama
# 46       1001  01   1.0    5   1022  2020    1    County  Alabama
# 47       1001  01   1.0    5   1023  2020    1    County  Alabama
# 48       1001  01   1.0    5   1024  2020    1    County  Alabama
# 49       1001  01   1.0    5   1025  2020    1    County  Alabama
# 50       1001  01   1.0    5   1026  2020    1    County  Alabama
# 51       1001  01   1.0    5   1027  2020    1    County  Alabama
# 52       1003  01   3.0    0     10  2020    1    County  Alabama
# 53       1003  01   3.0    1     10  2020    1    County  Alabama
# 54       1003  01   3.0    2     10  2020    1    County  Alabama
#
#                        Area  ...                                   Industry  \
# 35  autauga county, alabama  ...                   10 Total, all industries
# 36  autauga county, alabama  ...                   10 Total, all industries
# 37  autauga county, alabama  ...                   10 Total, all industries
# 38  autauga county, alabama  ...                   10 Total, all industries
# 39  autauga county, alabama  ...                   10 Total, all industries
# 40  autauga county, alabama  ...                        101 Goods-producing
# 41  autauga county, alabama  ...          1011 Natural resources and mining
# 42  autauga county, alabama  ...                          1012 Construction
# 43  autauga county, alabama  ...                         1013 Manufacturing
# 44  autauga county, alabama  ...                      102 Service-providing
# 45  autauga county, alabama  ...  1021 Trade, transportation, and utilities
# 46  autauga county, alabama  ...                           1022 Information
# 47  autauga county, alabama  ...                  1023 Financial activities
# 48  autauga county, alabama  ...    1024 Professional and business services
# 49  autauga county, alabama  ...         1025 Education and health services
# 50  autauga county, alabama  ...               1026 Leisure and hospitality
# 51  autauga county, alabama  ...                        1027 Other services
# 52  baldwin county, alabama  ...                   10 Total, all industries
# 53  baldwin county, alabama  ...                   10 Total, all industries
# 54  baldwin county, alabama  ...                   10 Total, all industries
#
#    Status Code Establishment Count  January Employment  February Employment  \
# 35         NaN                 910               11085                11047
# 36         NaN                  10                  81                   84
# 37         NaN                  19                 579                  586
# 38         NaN                  32                1903                 1925
# 39         NaN                 849                8522                 8452
# 40         NaN                 138                2320                 2241
# 41         NaN                  25                 178                  178
# 42         NaN                  90                 540                  476
# 43         NaN                  23                1602                 1587
# 44         NaN                 711                6202                 6211
# 45         NaN                 201                2135                 2122
# 46         NaN                   6                  27                   26
# 47         NaN                 120                 434                  434
# 48         NaN                 117                 616                  629
# 49         NaN                 101                1215                 1213
# 50         NaN                  88                1516                 1539
# 51         NaN                  78                 259                  248
# 52         NaN                6654               74015                75343
# 53         NaN                  34                 351                  349
# 54         NaN                  38                1070                 1219
#
#     March Employment  Total Quarterly Wages  Average Weekly Wage  \
# 35             11070              119509163                  831
# 36                85                1073296                  991
# 37               573                6926871                  920
# 38              1940               19222214                  769
# 39              8472               92286782                  837
# 40              2224               35980188                 1224
# 41               180                3034117                 1306
# 42               485                6528005                 1004
# 43              1559               26418066                 1284
# 44              6248               56306594                  696
# 45              2120               24402962                  883
# 46                26                 416992                 1218
# 47               429                5159261                  918
# 48               622                7860099                  972
# 49              1243               11066833                  696
# 50              1556                5431422                  272
# 51               252                1969025                  599
# 52             76061              720143752                  737
# 53               364                5076102                 1101
# 54              1211               11414846                  753
#
#     Employment Location Quotient Relative to U.S.  \
# 35                                           1.00
# 36                                           0.40
# 37                                           1.62
# 38                                           1.76
# 39                                           0.90
# 40                                           1.36
# 41                                           1.35
# 42                                           0.89
# 43                                           1.64
# 44                                           0.80
# 45                                           1.04
# 46                                           0.12
# 47                                           0.68
# 48                                           0.39
# 49                                           0.71
# 50                                           1.32
# 51                                           0.75
# 52                                           1.00
# 53                                           0.25
# 54                                           0.50
#
#     Total Wage Location Quotient Relative to U.S.
# 35                                           1.00
# 36                                           0.37
# 37                                           1.82
# 38                                           1.92
# 39                                           0.90
# 40                                           1.84
# 41                                           1.94
# 42                                           1.10
# 43                                           2.19
# 44                                           0.68
# 45                                           1.35
# 46                                           0.08
# 47                                           0.37
# 48                                           0.34
# 49                                           0.72
# 50                                           1.08
# 51                                           0.84
# 52                                           1.00
# 53                                           0.29
# 54                                           0.50
#
# [20 rows x 21 columns]

# %%
#Selecting rows based on few industries
emp_data=emp_data.loc[emp_data['Industry'].isin(['10 Total, all industries','1021 Trade, transportation, and utilities','1013 Manufacturing','1024 Professional and business services'])]

# %%
#Removing total covered as we can add up state,federal,local and private count to get that number
emp_data=emp_data.loc[emp_data['Ownership']!='Total Covered']

# %%
#Removing the rows wih status code as 'N' as they are not being updated
emp_data=emp_data.loc[emp_data['Status Code']!='N']

# %%
emp_data.columns
# Out:
# Index(['Area\nCode', 'St', 'Cnty', 'Own', 'NAICS', 'Year', 'Qtr', 'Area Type',
#        'St Name', 'Area', 'Ownership', 'Industry', 'Status Code',
#        'Establishment Count', 'January Employment', 'February Employment',
#        'March Employment', 'Total Quarterly Wages', 'Average Weekly Wage',
#        'Employment Location Quotient Relative to U.S.',
#        'Total Wage Location Quotient Relative to U.S.'],
#       dtype='object')

# %%
#Removing the unecessary variables
emp_data = emp_data.drop(['St','Cnty','NAICS','Year','Qtr','Area Type','Status Code'], 1)

# %%
#Removing some unknown or undefined data in counties
emp_data = emp_data[emp_data['Area'].str.contains('county', na=False)]

# %%
#Displaying the processed dataset
emp_data.head(20)
# Out:
#    Area\nCode  Own  St Name                     Area           Ownership  \
# 36       1001    1  Alabama  autauga county, alabama  Federal Government
# 37       1001    2  Alabama  autauga county, alabama    State Government
# 38       1001    3  Alabama  autauga county, alabama    Local Government
# 39       1001    5  Alabama  autauga county, alabama             Private
# 43       1001    5  Alabama  autauga county, alabama             Private
# 45       1001    5  Alabama  autauga county, alabama             Private
# 48       1001    5  Alabama  autauga county, alabama             Private
# 53       1003    1  Alabama  baldwin county, alabama  Federal Government
# 54       1003    2  Alabama  baldwin county, alabama    State Government
# 55       1003    3  Alabama  baldwin county, alabama    Local Government
# 56       1003    5  Alabama  baldwin county, alabama             Private
# 60       1003    5  Alabama  baldwin county, alabama             Private
# 62       1003    5  Alabama  baldwin county, alabama             Private
# 65       1003    5  Alabama  baldwin county, alabama             Private
# 70       1005    1  Alabama  barbour county, alabama  Federal Government
# 71       1005    2  Alabama  barbour county, alabama    State Government
# 72       1005    3  Alabama  barbour county, alabama    Local Government
# 73       1005    5  Alabama  barbour county, alabama             Private
# 77       1005    5  Alabama  barbour county, alabama             Private
# 79       1005    5  Alabama  barbour county, alabama             Private
#
#                                      Industry  Establishment Count  \
# 36                   10 Total, all industries                   10
# 37                   10 Total, all industries                   19
# 38                   10 Total, all industries                   32
# 39                   10 Total, all industries                  849
# 43                         1013 Manufacturing                   23
# 45  1021 Trade, transportation, and utilities                  201
# 48    1024 Professional and business services                  117
# 53                   10 Total, all industries                   34
# 54                   10 Total, all industries                   38
# 55                   10 Total, all industries                   91
# 56                   10 Total, all industries                 6491
# 60                         1013 Manufacturing                  213
# 62  1021 Trade, transportation, and utilities                 1526
# 65    1024 Professional and business services                 1018
# 70                   10 Total, all industries                    9
# 71                   10 Total, all industries                   18
# 72                   10 Total, all industries                   31
# 73                   10 Total, all industries                  510
# 77                         1013 Manufacturing                   29
# 79  1021 Trade, transportation, and utilities                  138
#
#     January Employment  February Employment  March Employment  \
# 36                  81                   84                85
# 37                 579                  586               573
# 38                1903                 1925              1940
# 39                8522                 8452              8472
# 43                1602                 1587              1559
# 45                2135                 2122              2120
# 48                 616                  629               622
# 53                 351                  349               364
# 54                1070                 1219              1211
# 55                8556                 8581              8690
# 56               64038                65194             65796
# 60                4175                 4162              4166
# 62               17623                17639             17661
# 65                6002                 6143              6297
# 70                  55                   53                55
# 71                 621                  616               623
# 72                 969                  987               985
# 73                6714                 6740              6747
# 77                2535                 2542              2512
# 79                1382                 1361              1356
#
#     Total Quarterly Wages  Average Weekly Wage  \
# 36                1073296                  991
# 37                6926871                  920
# 38               19222214                  769
# 39               92286782                  837
# 43               26418066                 1284
# 45               24402962                  883
# 48                7860099                  972
# 53                5076102                 1101
# 54               11414846                  753
# 55               92381972                  825
# 56              611270832                  723
# 60               54518988                 1006
# 62              160725716                  701
# 65               63676587                  797
# 70                 729178                 1032
# 71                6407512                  795
# 72                9071912                  712
# 73               64495651                  737
# 77               27408584                  833
# 79               13615524                  767
#
#     Employment Location Quotient Relative to U.S.  \
# 36                                           0.40
# 37                                           1.62
# 38                                           1.76
# 39                                           0.90
# 43                                           1.64
# 45                                           1.04
# 48                                           0.39
# 53                                           0.25
# 54                                           0.50
# 55                                           1.14
# 56                                           1.02
# 60                                           0.64
# 62                                           1.26
# 65                                           0.58
# 70                                           0.34
# 71                                           2.31
# 72                                           1.17
# 73                                           0.95
# 77                                           3.47
# 79                                           0.87
#
#     Total Wage Location Quotient Relative to U.S.
# 36                                           0.37
# 37                                           1.82
# 38                                           1.92
# 39                                           0.90
# 43                                           2.19
# 45                                           1.35
# 48                                           0.34
# 53                                           0.29
# 54                                           0.50
# 55                                           1.53
# 56                                           0.99
# 60                                           0.75
# 62                                           1.47
# 65                                           0.46
# 70                                           0.37
# 71                                           2.49
# 72                                           1.34
# 73                                           0.93
# 77                                           3.36
# 79                                           1.11

# %%
#Reading the covid super dataset
covid=pd.read_csv('../data/covid_large.csv')

# %%
#Converting object type to int to be able to merge the data with the countyFIPS column which is int
emp_data['Area\nCode']=emp_data['Area\nCode'].astype(str).astype(int)

# %% [markdown]
# #### Merging the original and enrichment dataset

# %%
df = pd.merge(covid,emp_data,left_on='countyFIPS',right_on='Area\nCode')

# %%
#Removing duplicate columns
df = df.drop(['Area\nCode','Area','St Name'], 1)

# %%
#Displaying the dataset
df
# Out:
#         State  countyFIPS     County Name        Date  Num of Cases  \
# 0          AL        1001  autauga county  2020-01-22             0
# 1          AL        1001  autauga county  2020-01-22             0
# 2          AL        1001  autauga county  2020-01-22             0
# 3          AL        1001  autauga county  2020-01-22             0
# 4          AL        1001  autauga county  2020-01-22             0
# ...       ...         ...             ...         ...           ...
# 4706578    WY       56045   weston county  2020-09-14            23
# 4706579    WY       56045   weston county  2020-09-14            23
# 4706580    WY       56045   weston county  2020-09-14            23
# 4706581    WY       56045   weston county  2020-09-14            23
# 4706582    WY       56045   weston county  2020-09-14            23
#
#          Num of Deaths  population  Own           Ownership  \
# 0                    0       55869    1  Federal Government
# 1                    0       55869    2    State Government
# 2                    0       55869    3    Local Government
# 3                    0       55869    5             Private
# 4                    0       55869    5             Private
# ...                ...         ...  ...                 ...
# 4706578              0        6927    2    State Government
# 4706579              0        6927    3    Local Government
# 4706580              0        6927    5             Private
# 4706581              0        6927    5             Private
# 4706582              0        6927    5             Private
#
#                                           Industry  Establishment Count  \
# 0                         10 Total, all industries                   10
# 1                         10 Total, all industries                   19
# 2                         10 Total, all industries                   32
# 3                         10 Total, all industries                  849
# 4                               1013 Manufacturing                   23
# ...                                            ...                  ...
# 4706578                   10 Total, all industries                   12
# 4706579                   10 Total, all industries                   21
# 4706580                   10 Total, all industries                  250
# 4706581  1021 Trade, transportation, and utilities                   61
# 4706582    1024 Professional and business services                   23
#
#          January Employment  February Employment  March Employment  \
# 0                        81                   84                85
# 1                       579                  586               573
# 2                      1903                 1925              1940
# 3                      8522                 8452              8472
# 4                      1602                 1587              1559
# ...                     ...                  ...               ...
# 4706578                 144                  143               143
# 4706579                 626                  631               630
# 4706580                1518                 1508              1465
# 4706581                 416                  408               407
# 4706582                  49                   52                55
#
#          Total Quarterly Wages  Average Weekly Wage  \
# 0                      1073296                  991
# 1                      6926871                  920
# 2                     19222214                  769
# 3                     92286782                  837
# 4                     26418066                 1284
# ...                        ...                  ...
# 4706578                1863234                 1000
# 4706579                5906403                  722
# 4706580               16128384                  829
# 4706581                3326262                  624
# 4706582                 607137                  898
#
#          Employment Location Quotient Relative to U.S.  \
# 0                                                 0.40
# 1                                                 1.62
# 2                                                 1.76
# 3                                                 0.90
# 4                                                 1.64
# ...                                                ...
# 4706578                                           1.95
# 4706579                                           2.76
# 4706580                                           0.75
# 4706581                                           0.96
# 4706582                                           0.17
#
#          Total Wage Location Quotient Relative to U.S.
# 0                                                 0.37
# 1                                                 1.82
# 2                                                 1.92
# 3                                                 0.90
# 4                                                 2.19
# ...                                                ...
# 4706578                                           2.38
# 4706579                                           2.88
# 4706580                                           0.76
# 4706581                                           0.89
# 4706582                                           0.13
#
# [4706583 rows x 18 columns]

# %%
#Exporting part of the merged dataset to a csv file
df[:700000].to_csv('../data/emp_covid.csv',index=False)

# %%
df.dtypes
# Out:
# State                                             object
# countyFIPS                                         int64
# County Name                                       object
# Date                                              object
# Num of Cases                                       int64
# Num of Deaths                                      int64
# population                                         int64
# Own                                                int64
# Ownership                                         object
# Industry                                          object
# Establishment Count                                int64
# January Employment                                 int64
# February Employment                                int64
# March Employment                                   int64
# Total Quarterly Wages                              int64
# Average Weekly Wage                                int64
# Employment Location Quotient Relative to U.S.    float64
# Total Wage Location Quotient Relative to U.S.    float64
# dtype: object
